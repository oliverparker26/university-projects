# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('archive\StudentsPerformance.csv')
data
df = pd.read_csv('archiveeee/xAPI-Edu-Data.csv')
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
data['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
rating = {'some high school' : 1, 'high school' :2, 
          'some college' : 3, "associate's degree" : 4,
          "bachelor's degree" : 5, "master's degree" : 6
}
yes = {'none' : 0, 'completed' : 1
}
a = []
b = []
for i in range(0, len(data['parental level of education'])):
    a.append(rating[data['parental level of education'][i]])
    b.append(yes[data['test preparation course'][i]])
data['rating'] = a
data['yes'] = b
data[['math score', 'rating', 'yes']].corr()
# Out:
#             math score    rating       yes
# math score    1.000000  0.159432  0.177702
# rating        0.159432  1.000000 -0.007143
# yes           0.177702 -0.007143  1.000000

# %%
data.groupby('parental level of education')[['math score', 'reading score', 'writing score']].mean()
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
data.groupby('gender')[['math score', 'reading score', 'writing score']].mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
data.groupby('gender')[['math score', 'reading score', 'writing score']].median()
# Out:
#         math score  reading score  writing score
# gender
# female        65.0           73.0           74.0
# male          69.0           66.0           64.0

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
rrr = []
tt = []
t = []
l = []
marks = {'G-01' :1,
         'G-02':2,
         'G-03':3,
         'G-04':4,
         'G-05':5,
         'G-06':6,
         'G-07':7,
         'G-08':8,
         'G-09':9,
         'G-10':10,
         'G-11':11,
         'G-12':12}
yess = {'Under-7' : 1,
       'Above-7' : 0,
       'Good' : 1,
       'Bad' : 0,
       'Yes' :1,
       'No' : 0}

for i in range(0, len(df['GradeID'])):
    rrr.append(marks[df['GradeID'][i]])
    tt.append(yess[df['StudentAbsenceDays'][i]])
    t.append(yess[df['ParentschoolSatisfaction'][i]])
    l.append(yess[df['ParentAnsweringSurvey'][i]])
df['Marks'] = rrr
df["Abs"] = tt
df['Sat'] = t
df['Survey'] = l
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  ...  AnnouncementsView  \
# 0           IT        F   Father           15  ...                  2
# ...

# %%
df.groupby('Relation')['Marks'].mean()
# Out:
# Relation
# Father    5.681979
# Mum       5.482234
# Name: Marks, dtype: float64

# %%
df.groupby(['gender', 'Topic'])['Marks'].mean()
# Out:
# gender  Topic
# F       Arabic       5.000000
#         Biology      7.000000
#         Chemistry    8.000000
#         English      8.210526
#         French       2.300000
#         Geology      8.000000
#         History      6.000000
#         IT           4.156250
#         Math         7.000000
#         Quran        7.777778
#         Science      5.347826
#         Spanish      8.000000
# M       Arabic       4.837209
#         Biology      7.000000
#         Chemistry    8.000000
#         English      6.615385
#         French       2.000000
#         Geology      8.000000
#         History      6.909091
#         IT           4.238095
#         Math         7.250000
#         Quran        7.615385
#         Science      6.035714
#         Spanish      8.125000
# Name: Marks, dtype: float64

# %%
df[['raisedhands', 'Marks', 'VisITedResources']].corr()
# Out:
#                   raisedhands     Marks  VisITedResources
# raisedhands          1.000000  0.194382          0.691572
# Marks                0.194382  1.000000          0.078741
# VisITedResources     0.691572  0.078741          1.000000

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class', 'Marks', 'Abs', 'Sat', 'Survey'],
#       dtype='object')

# %%
df[['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
       'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
       'VisITedResources', 'AnnouncementsView', 'Discussion',
       'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
       'StudentAbsenceDays', 'Class', 'Marks', 'Abs', 'Sat', 'Survey']].corr()
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.691572           0.643918
# VisITedResources      0.691572          1.000000           0.594500
# AnnouncementsView     0.643918          0.594500           1.000000
# Discussion            0.339386          0.243292           0.417290
# Marks                 0.194382          0.078741           0.198552
# Abs                   0.463882          0.499030           0.312134
# Sat                   0.297015          0.363835           0.298744
# Survey                0.316570          0.382472           0.396357
#
#                    Discussion     Marks       Abs       Sat    Survey
# raisedhands          0.339386  0.194382  0.463882  0.297015  0.316570
# VisITedResources     0.243292  0.078741  0.499030  0.363835  0.382472
# AnnouncementsView    0.417290  0.198552  0.312134  0.298744  0.396357
# Discussion           1.000000  0.180966  0.218778  0.061104  0.232197
# ...

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  ...  AnnouncementsView  \
# 0           IT        F   Father           15  ...                  2
# ...

# %%
dff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1744/2703340203.py in <module>
# ----> 1 dff
#
# NameError: name 'dff' is not defined

# %%
df.groupby(['gender', 'Relation', 'ParentAnsweringSurvey', 'ParentschoolSatisfaction', 'StageID']).Marks.mean()
# Out:
# gender  Relation  ParentAnsweringSurvey  ParentschoolSatisfaction  StageID
# F       Father    No                     Bad                       HighSchool      11.250000
#                                                                    MiddleSchool     7.500000
#                                                                    lowerlevel       2.461538
#                                          Good                      MiddleSchool     7.000000
#                                                                    lowerlevel       2.333333
#                   Yes                    Bad                       HighSchool      11.000000
#                                                                    MiddleSchool     7.000000
#                                                                    lowerlevel       3.200000
#                                          Good                      HighSchool      10.666667
# ...

# %%
df[['Class', 'Abs']].corr()
# Out:
#      Abs
# Abs  1.0

# %%
dat
# Out:
#        age          workclass  fnlwgt  education  education-num  \
# 0       39          State-gov   77516        NaN             13
# 1       50   Self-emp-not-inc   83311        NaN             13
# 2       38            Private  215646        NaN              9
# 3       53            Private  234721        NaN              7
# 4       28            Private  338409        NaN             13
# ...    ...                ...     ...        ...            ...
# 32556   27            Private  257302        9.0             12
# 32557   40            Private  154374        NaN              9
# 32558   58            Private  151910        NaN              9
# 32559   22            Private  201490        NaN              9
# 32560   52       Self-emp-inc  287927        NaN              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
d = pd.ExcelFile('WAGES.xls')
dd = pd.read_excel(d, 'Sheet1')

# %%
dd
# Out:
#       EXP  WKS  OCC  IND  SOUTH  SMSA  MS  FEM  UNION  ED  BLK    LWAGE
# 0       3   32    0    0      1     0   1    0      0   9    0  5.56068
# 1       4   43    0    0      1     0   1    0      0   9    0  5.72031
# 2       5   40    0    0      1     0   1    0      0   9    0  5.99645
# 3       6   39    0    0      1     0   1    0      0   9    0  5.99645
# 4       7   42    0    1      1     0   1    0      0   9    0  6.06146
# ...   ...  ...  ...  ...    ...   ...  ..  ...    ...  ..  ...      ...
# 4160    3   50    0    0      0     1   0    1      0  12    0  5.95324
# 4161    4   49    0    0      0     1   0    1      0  12    0  6.06379
# 4162    5   50    0    0      0     1   0    1      0  12    0  6.21461
# 4163    6   50    0    0      0     1   0    1      0  12    0  6.29157
# 4164    7   50    0    0      0     1   0    1      0  12    0  6.37161
#
# [4165 rows x 12 columns]

# %%
dd[['EXP', 'WKS', 'OCC', 'IND', 'MS', 'FEM', 'UNION', 'ED',
       'BLK', 'LWAGE']].corr().LWAGE
sns.lineplot(x = 'EXP', y = 'LWAGE', data = dd, ci = None);

# %%
sns.lineplot(x = 'EXP', y = 'LWAGE', data = dd, ci = None);

# %%
dd.columns
# Out:
# Index(['EXP', 'WKS', 'OCC', 'IND', 'SOUTH', 'SMSA', 'MS', 'FEM', 'UNION', 'ED',
#        'BLK', 'LWAGE'],
#       dtype='object')

# %%
mask = ['<=50K']
dat['income less than 50K?'] = dat['income'].isin(mask)

# %%
dat[['age', 'income less than 50K?']].corr()
# Out:
#                        age  income less than 50K?
# age                    1.0                    NaN
# income less than 50K?  NaN                    NaN

# %%
dat['income less than 50K?']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: income less than 50K?, Length: 32561, dtype: bool

# %%
dat['income'].isin(mask)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: income, Length: 32561, dtype: bool

# %%
new = pd.read_csv('archi/aug_train.csv')
new
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
new.groupby(['experience', 'last_new_job']).target.mean().plot();

# %%
new.experience.unique()
young = ['<1', '1','2', '3', '4', '5','6']
middle = ['7','8', '9','10','11','12','13']
old = ['>20', '19', '18','17','16', '15','14']

# %%
new.groupby('experience')['target'].mean().nlargest()
# Out:
# experience
# <1    0.454023
# 1     0.424408
# 3     0.353028
# 2     0.331854
# 4     0.325731
# Name: target, dtype: float64

# %%
q = new[new.experience.isin(young)]['target'].mean()

# %%
w = new[new.experience.isin(middle)]['target'].mean()

# %%
e = new[new.experience.isin(old)]['target'].mean()

# %%
dfff = pd.DataFrame({'lab':['young', 'medium', 'old'], 'val':[q,w,e]})
ax = dfff.plot.bar(x='lab', y='val', rot=0)

# %%
new['last_new_job'].unique()
# Out:
# array(['1', '>4', 'never', '4', '3', '2', nan], dtype=object)

# %%
new.groupby('last_new_job')['target'].mean()
# Out:
# last_new_job
# 1        0.264303
# 2        0.241379
# 3        0.225586
# 4        0.221574
# >4       0.182371
# never    0.301387
# Name: target, dtype: float64

# %%
new[new['last_new_job'] == '1'].experience.value_counts()
# Out:
# >20    792
# 5      736
# 4      736
# 3      661
# 6      622
# 2      593
# 7      479
# 10     432
# 9      422
# 8      382
# 1      313
# 11     292
# 14     235
# <1     234
# 15     227
# 12     196
# 16     163
# 13     148
# 17     123
# 19      94
# 18      90
# 20      49
# Name: experience, dtype: int64

# %%
dicti = {'<1': 1, '1': 1,'2': 1, '3': 1, '4': 1, '5': 1,'6' : 1, 
        '7': 2,'8': 2, '9': 2,'10': 2,'11': 2,'12': 2,'13' : 2,
        '>20': 3,'20': 3, '19': 3, '18': 3,'17': 3,'16': 3, '15': 3,'14' : 3}
new.experience[1]
# Out:
# '15'

# %%
aaa = []
www = new.experience.dropna()
for i in range(0, len(new.experience)):
    if(type(new.experience[i]) == str):
        aaa.append(dicti[www[i]])
    else:
        aaa.append(0)
aaa
new['exp'] = aaa
new
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
new[['experience', 'education_level']]
# Out:
#       experience education_level
# 0            >20        Graduate
# 1             15        Graduate
# 2              5        Graduate
# 3             <1        Graduate
# 4            >20         Masters
# ...          ...             ...
# 19153         14        Graduate
# 19154         14        Graduate
# 19155        >20        Graduate
# 19156         <1     High School
# 19157          2  Primary School
#
# [19158 rows x 2 columns]

# %%
new.groupby('exp')['target'].mean()
# Out:
# exp
# 0    0.353846
# 1    0.333377
# 2    0.231315
# 3    0.159935
# Name: target, dtype: float64

# %%
new.groupby('exp')['training_hours'].mean()
# Out:
# exp
# 0    71.723077
# 1    65.323247
# 2    65.244021
# 3    65.460749
# Name: training_hours, dtype: float64

# %%
new[new.exp == 1][['education_level']].value_counts()
# Out:
# education_level
# Graduate           4671
# High School        1315
# Masters            1085
# Primary School      222
# Phd                  33
# dtype: int64

# %%
new[new.exp == 2][['education_level']].value_counts()
# Out:
# education_level
# Graduate           3322
# Masters            1373
# High School         432
# Phd                  84
# Primary School       64
# dtype: int64

# %%
new[new.exp == 3][['education_level']].value_counts()
# Out:
# education_level
# Graduate           3573
# Masters            1888
# Phd                 294
# High School         266
# Primary School       21
# dtype: int64

# %%
dfff = pd.DataFrame({'возрастные категории':['young', 'medium', 'old'], 'среднее желание сменить работу':[q,w,e]})
ax = dfff.plot.bar(x='возрастные категории', y='среднее желание сменить работу', rot=0)

# %%
print(new.groupby('exp')['training_hours'].mean()[[1,2,3]])
new.groupby('exp')['training_hours'].mean()[[1,2,3]].plot.bar(color = {'red','yellow','green'});
# Out:
# exp
# 1    65.323247
# 2    65.244021
# 3    65.460749
# Name: training_hours, dtype: float64

# %%
columns = ['age' ,'workclass', 'fnlwgt','education','education-num','marital-status','occupation',
'relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country', 'income']
dat = pd.read_csv('archiv/adult-training.csv', names = columns)

# %%
dat
dat['income tr'] = dat['income'].map({' <=50K': 0, ' >50K': 1})
dat
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dat.groupby('age')['income tr'].mean().plot(kind = 'bar');

# %%
#1) заработки обычно повышаются с возрастом, но затухающим
#темпом; и темп их роста, и степень его замедления положительно связанны с уровнем образования; 
#темпом; и темп их роста, и степень его замедления положительно связанны с уровнем образования;
dat.groupby('age')['income tr'].mean().plot(kind = 'line');

# %%
dat[dat.education == ' 1st-4th'].groupby('age')['income tr'].mean().plot(kind = 'line');

# %%
dat[dat.education == ' 11th'].groupby('age')['income tr'].mean().plot(kind = 'line');

# %%
dat[dat.education == ' Bachelors'].groupby('age')['income tr'].mean().plot(kind = 'line');

# %%
dat[dat.education == ' Masters'].groupby('age')['income tr'].mean().plot(kind = 'line');

# %%
#2) нормы безработицы отрицательно связаны с уровнем образования; 
dat[dat['workclass'] == ' Never-worked']['education-num'].mean()
# Out:
# 7.428571428571429

# %%
un[un['Month'] == 'Jan'][['Primary_School', 'High_School', 'Associates_Degree', 'Professional_Degree']].plot();

# %%
#3) молодёжь чаще меняет место работы и получает более высокое
#образование и лучшую подготовку на производстве, чем лица пожилого возраста; 
dicti = {'<1': 1, '1': 1,'2': 1, '3': 1, '4': 1, '5': 1,'6' : 1, 
        '7': 2,'8': 2, '9': 2,'10': 2,'11': 2,'12': 2,'13' : 2,
        '>20': 3,'20': 3, '19': 3, '18': 3,'17': 3,'16': 3, '15': 3,'14' : 3}
new.groupby('exp')['target'].mean()[[1,2,3]]
# Out:
# exp
# 1    0.333377
# 2    0.231315
# 3    0.159935
# Name: target, dtype: float64

# %%
print(new.groupby('exp')['training_hours'].mean()[[1,2,3]])
new.groupby('exp')['training_hours'].mean()[[1,2,3]].plot.bar(color = {'red','yellow','green'});
# Out:
# exp
# 1    65.323247
# 2    65.244021
# 3    65.460749
# Name: training_hours, dtype: float64

# %%
dat.groupby('education')['income tr'].mean().plot();

# %%
dat.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
dat.groupby('workclass')['income tr'].mean()
dat[dat['workclass'] == ' Self-emp-inc'].age.mean()
dat.groupby('workclass')[['age','income tr', 'education-num']].mean()
# Out:
#                          age  income tr  education-num
# workclass
#  ?                 40.960240   0.104031       9.260349
#  Federal-gov       42.590625   0.386458      10.973958
#  Local-gov         41.751075   0.294792      11.042045
#  Never-worked      20.571429   0.000000       7.428571
#  Private           36.797585   0.218673       9.879714
#  Self-emp-inc      46.017025   0.557348      11.137097
#  Self-emp-not-inc  44.969697   0.284927      10.226289
#  State-gov         39.436055   0.271957      11.375963
#  Without-pay       47.785714   0.000000       9.071429

# %%
dat.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
new
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
dat['education 1'] = dat['education'].map({' Some-college': 0, ' Preschool': 1, 
                                                        ' 5th-6th': 2, 'HS-grad': 3, ' Masters': 4, 
                                                        ' 12th': 5, ' 7th-8th': 6, ' Prof-school': 7,
                                                        ' 1st-4th': 8, ' Assoc-acdm': 9,
                                                        ' Doctorate': 10, '11th': 11,
                                                        'Bachelors': 12, ' 10th': 13,
                                                        ' Assoc-voc': 14,
                                                        '9th': 15})
dat
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dat.groupby(['native-country'])['hours-per-week'].mean().nlargest()
# Out:
# native-country
#  Thailand      45.444444
#  France        45.068966
#  Yugoslavia    44.562500
#  Greece        44.241379
#  Iran          43.976744
# Name: hours-per-week, dtype: float64

# %%
dat.groupby(['occupation'])['hours-per-week'].mean().nlargest()
# Out:
# occupation
#  Farming-fishing     46.989940
#  Exec-managerial     44.987703
#  Transport-moving    44.656230
#  Protective-serv     42.870570
#  Prof-specialty      42.386715
# Name: hours-per-week, dtype: float64

# %%
dat[dat['occupation'] == ' Sales'].groupby('native-country')['hours-per-week'].mean().nlargest()
# Out:
# native-country
#  Outlying-US(Guam-USVI-etc)    55.0
#  Dominican-Republic            50.0
#  Taiwan                        50.0
#  France                        47.5
#  Japan                         47.0
# Name: hours-per-week, dtype: float64

# %%
dat.occupation.unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
sns.lineplot(data = dat, x = 'age', y = 'hours-per-week', ci = None);

# %%
print(dat.groupby('education')['income tr'].mean().sort_values())
columns = [[' Preschool',
                                                                ' 1st-4th', 
                                                                ' 5th-6th',
                                                                ' 7th-8th',
                                                                ' 9th',
                                                                ' 10th',
                                                                ' 11th',
                                                                ' 12th'
                                                                ' Some-college',
                                                                ' HS-grad',
                                                                ' Prof-school',
                                                                ' Assoc-acdm',
                                                                ' Assoc-voc',
                                                                ' Bachelors',   
                                                                ' Masters', 
                                                                ' Doctorate']]
dat.groupby('education')['income tr'].mean().plot.bar();
dat.groupby('education-num')['income tr'].mean().plot.bar();
# Out:
# education
#  Preschool       0.000000
#  1st-4th         0.035714
#  5th-6th         0.048048
#  11th            0.051064
#  9th             0.052529
#  7th-8th         0.061920
#  10th            0.066452
#  12th            0.076212
#  HS-grad         0.159509
#  Some-college    0.190235
#  Assoc-acdm      0.248360
#  Assoc-voc       0.261216
#  Bachelors       0.414753
#  Masters         0.556587
#  Prof-school     0.734375
#  Doctorate       0.740920
# Name: income tr, dtype: float64

# %%
dat[['education-num', 'income tr']].corr()
# Out:
#                education-num  income tr
# education-num       1.000000   0.335154
# income tr           0.335154   1.000000

# %%
sns.barplot(x = 'education', y = dat.groupby('education')['income tr'].mean(), data = dat);

# %%
un = pd.read_csv('archivee/unemployment_data_us.csv')
un = un.dropna(how = 'any')

# %%
un[un['Month'] == 'Jan']['Primary_School']
# Out:
# 0     15.3
# 1     14.3
# 2     13.0
# 3     12.0
# 4      9.4
# 5      8.3
# 6      7.1
# 7      7.4
# 8      5.4
# 9      5.7
# 10     5.5
# Name: Primary_School, dtype: float64

# %%
un
# Out:
#      Year Month  Primary_School      Date  High_School  Associates_Degree  \
# 0    2010   Jan            15.3  Jan-2010         10.2                8.6
# 1    2011   Jan            14.3  Jan-2011          9.5                8.1
# 2    2012   Jan            13.0  Jan-2012          8.5                7.1
# 3    2013   Jan            12.0  Jan-2013          8.1                6.9
# 4    2014   Jan             9.4  Jan-2014          6.5                5.9
# ..    ...   ...             ...       ...          ...                ...
# 126  2015   Dec             6.4  Dec-2015          5.6                4.1
# 127  2016   Dec             7.5  Dec-2016          5.1                3.8
# 128  2017   Dec             6.2  Dec-2017          4.2                3.6
# 129  2018   Dec             5.8  Dec-2018          3.8                3.3
# 130  2019   Dec             5.2  Dec-2019          3.7                2.7
#
#      Professional_Degree  White  Black  Asian  Hispanic   Men  Women
# ...

# %%
new.groupby('relevent_experience')['target'].mean()
# Out:
# relevent_experience
# Has relevent experience    0.214690
# No relevent experience     0.338427
# Name: target, dtype: float64

# %%
new['rel'] = new['relevent_experience'].map({'Has relevent experience' : 1, 'No relevent experience' : 0})
new['company_size'].unique()
# Out:
# array([nan, '50-99', '<10', '10000+', '5000-9999', '1000-4999', '10/49',
#        '100-500', '500-999'], dtype=object)

# %%
new.dropna(how='any').groupby('company_size')['rel'].mean().sort_values()
# Out:
# company_size
# 10000+       0.844030
# 1000-4999    0.853763
# 5000-9999    0.857506
# 500-999      0.859797
# 10/49        0.888538
# <10          0.889286
# 50-99        0.893253
# 100-500      0.894157
# Name: rel, dtype: float64

# %%
dat.groupby
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...
