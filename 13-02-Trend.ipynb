# %%
import pandas as pd
import pandas_datareader.data as web
import pandas_datareader as pdr
import seaborn as sns

# %%
f = web.DataReader('USD000UTSTOM', 'moex', start='2017-07-01', end='2017-07-31')
f.head()
# Out:
#            BOARDID    CLOSE     HIGH      LOW NUMTRADES     OPEN  \
# TRADEDATE
# 2017-07-03    CETS  59.2650  59.4825  58.7900     29108  58.9500
# 2017-07-04    CETS  59.4125  59.4575  59.1350     21053  59.3000
# 2017-07-05    CETS  59.9825  60.2600  59.3000     50108  59.3000
# 2017-07-06    CETS  60.1600  60.4350  59.7500     43929  60.1025
# 2017-07-07    CETS  60.3550  60.6250  60.2125     45691  60.4000
#
#                    SECID   SHORTNAME        VOLRUR  WAPRICE
# TRADEDATE
# 2017-07-03  USD000UTSTOM  USDRUB_TOM  1.472424e+11  59.1903
# 2017-07-04  USD000UTSTOM  USDRUB_TOM  1.090265e+11  59.2700
# 2017-07-05  USD000UTSTOM  USDRUB_TOM  2.874226e+11  59.9234
# 2017-07-06  USD000UTSTOM  USDRUB_TOM  2.404461e+11  60.0714
# 2017-07-07  USD000UTSTOM  USDRUB_TOM  2.561535e+11  60.4281

# %%
sber=web.DataReader('sber', 'moex', start='2017-01-01', end='2017-12-31')
sber.head()
# Out:
#             ADMITTEDQUOTE  ADMITTEDVALUE  BEICLOSE  BID BOARDID BOARDNAME  \
# TRADEDATE
# 2017-01-03         180.12   9.609078e+09       NaN  NaN    TQBR       NaN
# 2017-01-04         175.95   7.305516e+09       NaN  NaN    TQBR       NaN
# 2017-01-05         171.90   6.109243e+09       NaN  NaN    TQBR       NaN
# 2017-01-06         170.69   6.065098e+09       NaN  NaN    TQBR       NaN
# 2017-01-09         168.35   5.977865e+09       NaN  NaN    TQBR       NaN
#
#             BUYBACKDATE  CBRCLOSE   CLOSE CLOSEAUCTIONPRICE  ... TRENDCLSPR  \
# TRADEDATE                                                    ...
# 2017-01-03          NaN       NaN  180.12               NaN  ...        NaN
# 2017-01-04          NaN       NaN  175.95               NaN  ...        NaN
# 2017-01-05          NaN       NaN  171.90               NaN  ...        NaN
# 2017-01-06          NaN       NaN  170.69               NaN  ...        NaN
# 2017-01-09          NaN       NaN  168.35               NaN  ...        NaN
#
#            TRENDWAP  TRENDWAPPR  TYPE         VALUE      VOLUME  WAPRICE  \
# TRADEDATE
# 2017-01-03      NaN         NaN   NaN  9.609078e+09  53890400.0   178.25
# 2017-01-04      NaN         NaN   NaN  7.305516e+09  41400710.0   176.50
# 2017-01-05      NaN         NaN   NaN  6.109243e+09  35093040.0   174.13
# 2017-01-06      NaN         NaN   NaN  6.065098e+09  35415590.0   171.28
# 2017-01-09      NaN         NaN   NaN  5.977865e+09  35187380.0   169.90
#
#            WAVAL  YIELDLASTCOUPON  YIELDTOOFFER
# TRADEDATE
# 2017-01-03   NaN              NaN           NaN
# 2017-01-04   NaN              NaN           NaN
# 2017-01-05   NaN              NaN           NaN
# 2017-01-06   NaN              NaN           NaN
# 2017-01-09   NaN              NaN           NaN
#
# [5 rows x 65 columns]

# %%
f = pdr.moex.MoexReader('SBER', '2020-07-02', '2020-07-03').read_all_boards()
f.head(10)
# Out:
#             ADMITTEDQUOTE  ADMITTEDVALUE  BEICLOSE  BID BOARDID BOARDNAME  \
# TRADEDATE
# 2020-07-02            NaN            NaN       NaN  NaN    EQRP       NaN
# 2020-07-02            NaN            NaN       NaN  NaN    PSRD       NaN
# 2020-07-02            NaN            NaN       NaN  NaN    PSRP       NaN
# 2020-07-03            NaN            NaN       NaN  NaN    EQRP       NaN
# 2020-07-03            NaN            NaN       NaN  NaN    PSRD       NaN
# 2020-07-03            NaN            NaN       NaN  NaN    PSRP       NaN
# 2020-07-02            NaN            NaN       NaN  NaN    RPMO       NaN
# 2020-07-03            NaN            NaN       NaN  NaN    RPMO       NaN
# 2020-07-03            NaN            NaN       NaN  NaN    SOTC       NaN
# 2020-07-02            NaN            NaN       NaN  NaN    PTEQ       NaN
#
#             BUYBACKDATE  CBRCLOSE   CLOSE CLOSEAUCTIONPRICE  ... TRENDCLSPR  \
# TRADEDATE                                                    ...
# 2020-07-02          NaN       NaN    4.25               NaN  ...        NaN
# 2020-07-02          NaN       NaN    0.65               NaN  ...        NaN
# 2020-07-02          NaN       NaN    4.50               NaN  ...        NaN
# 2020-07-03          NaN       NaN    2.90               NaN  ...        NaN
# 2020-07-03          NaN       NaN    1.90               NaN  ...        NaN
# 2020-07-03          NaN       NaN    4.49               NaN  ...        NaN
# 2020-07-02          NaN       NaN  209.50               NaN  ...        NaN
# 2020-07-03          NaN       NaN  210.59               NaN  ...        NaN
# 2020-07-03          NaN       NaN     NaN               NaN  ...        NaN
# 2020-07-02          NaN       NaN  210.00               NaN  ...        NaN
#
#            TRENDWAP  TRENDWAPPR          TYPE         VALUE     VOLUME  \
# TRADEDATE
# 2020-07-02      NaN         NaN           NaN  8.000984e+09        NaN
# 2020-07-02      NaN         NaN           NaN  1.125761e+07        NaN
# 2020-07-02      NaN         NaN           NaN  1.448042e+09        NaN
# 2020-07-03      NaN         NaN           NaN  1.247663e+10        NaN
# 2020-07-03      NaN         NaN           NaN  8.600262e+06        NaN
# 2020-07-03      NaN         NaN           NaN  5.984653e+09        NaN
# 2020-07-02      NaN         NaN           NaN  1.790613e+09        NaN
# 2020-07-03      NaN         NaN           NaN  1.836143e+09        NaN
# 2020-07-03      NaN         NaN  common_share  3.375344e+08  1618706.0
# 2020-07-02      NaN         NaN           NaN  1.902915e+08   914392.0
#
#               WAPRICE WAVAL  YIELDLASTCOUPON  YIELDTOOFFER
# TRADEDATE
# 2020-07-02    3.93000   NaN              NaN           NaN
# 2020-07-02        NaN   NaN              NaN           NaN
# 2020-07-02        NaN   NaN              NaN           NaN
# 2020-07-03    3.34000   NaN              NaN           NaN
# 2020-07-03        NaN   NaN              NaN           NaN
# 2020-07-03        NaN   NaN              NaN           NaN
# 2020-07-02        NaN   NaN              NaN           NaN
# 2020-07-03        NaN   NaN              NaN           NaN
# 2020-07-03  208.52136   NaN              NaN           NaN
# 2020-07-02  208.11000   NaN              NaN           NaN
#
# [10 rows x 65 columns]

# %%
f.BOARDID.unique()
# Out:
# array(['EQRP', 'PSRD', 'PSRP', 'RPMO', 'SOTC', 'PTEQ', 'SMAL', 'TQBR',
#        'MXBD'], dtype=object)

# %%
print(sber.columns)
# Out:
# Index(['ADMITTEDQUOTE', 'ADMITTEDVALUE', 'BEICLOSE', 'BID', 'BOARDID',
#        'BOARDNAME', 'BUYBACKDATE', 'CBRCLOSE', 'CLOSE', 'CLOSEAUCTIONPRICE',
#        'CLOSEPERIOD', 'CLOSEVAL', 'COUPONPERCENT', 'COUPONVALUE', 'CURRENCYID',
#        'DAILYCAPITALIZATION', 'DECIMALS', 'FACEUNIT', 'FACEVALUE', 'HIGH',
#        'HIGHBID', 'IRICPICLOSE', 'ISIN', 'ISSUESIZE', 'LASTPRICE',
#        'LASTTRADEDATE', 'LEGALCLOSEPRICE', 'LEGALOPENPRICE', 'LISTNAME', 'LOW',
#        'LOWOFFER', 'MARKETPRICE', 'MARKETPRICE2', 'MARKETPRICE3',
#        'MARKETPRICE3CUR', 'MARKETPRICE3TRADESVALUE',
#        'MARKETPRICE3TRADESVALUECUR', 'MONTHLYCAPITALIZATION', 'MP2VALTRD',
#        'MPVALTRD', 'NUMBID', 'NUMOFFER', 'NUMTRADES', 'OFFER', 'OFFERDATE',
#        'OPEN', 'OPENPERIOD', 'OPENVAL', 'PREV', 'PREVLEGALCLOSEPRICE',
#        'REGNUMBER', 'SECID', 'SHORTNAME', 'TRADINGSESSION', 'TRENDCLOSE',
#        'TRENDCLSPR', 'TRENDWAP', 'TRENDWAPPR', 'TYPE', 'VALUE', 'VOLUME',
#        'WAPRICE', 'WAVAL', 'YIELDLASTCOUPON', 'YIELDTOOFFER'],
#       dtype='object')

# %%
sbr=sber[['OPEN','LOW','HIGH','CLOSE','VALUE', 'VOLUME']]
sbr.head(20)
# Out:
#               OPEN     LOW    HIGH   CLOSE         VALUE      VOLUME
# TRADEDATE
# 2017-01-03  173.40  173.00  181.68  180.12  9.609078e+09  53890400.0
# 2017-01-04  178.90  174.23  179.41  175.95  7.305516e+09  41400710.0
# 2017-01-05  176.31  171.54  177.28  171.90  6.109243e+09  35093040.0
# 2017-01-06  172.40  169.50  173.75  170.69  6.065098e+09  35415590.0
# 2017-01-09  171.37  168.05  172.39  168.35  5.977865e+09  35187380.0
# 2017-01-10  168.35  167.54  172.30  171.60  1.007130e+10  58874120.0
# 2017-01-11  171.50  168.54  173.05  169.05  9.012624e+09  52772790.0
# 2017-01-12  170.00  168.02  170.65  168.27  8.442987e+09  49854940.0
# 2017-01-13  168.79  163.88  172.39  164.90  1.430459e+10  85990570.0
# 2017-01-16  165.22  164.06  166.80  164.66  6.218641e+09  37577470.0
# 2017-01-17  164.67  163.34  166.47  165.98  7.583760e+09  45968310.0
# 2017-01-18  165.90  164.31  167.80  165.24  7.051446e+09  42479900.0
# 2017-01-19  165.46  164.69  166.99  166.30  6.375017e+09  38478840.0
# 2017-01-20  166.55  165.42  168.19  167.49  5.439249e+09  32581460.0
# 2017-01-23  167.33  164.53  167.33  166.75  6.047502e+09  36457470.0
# 2017-01-24  167.37  167.24  170.70  170.25  7.685358e+09  45397860.0
# 2017-01-25  170.50  169.50  171.30  170.26  7.244602e+09  42543080.0
# 2017-01-26  170.85  169.06  174.39  173.79  9.680053e+09  56105000.0
# 2017-01-27  173.89  173.00  178.92  178.92  1.247494e+10  71123150.0
# 2017-01-30  177.50  174.24  178.00  174.60  8.087213e+09  45935720.0

# %%
sbr_vol_month=sbr.VALUE.resample('m').sum()
sbr_vol_month
# Out:
# TRADEDATE
# 2017-01-31    1.688358e+11
# 2017-02-28    1.362066e+11
# 2017-03-31    1.578608e+11
# 2017-04-30    1.532111e+11
# 2017-05-31    1.370957e+11
# 2017-06-30    1.825825e+11
# 2017-07-31    1.674641e+11
# 2017-08-31    1.859565e+11
# 2017-09-30    1.775828e+11
# 2017-10-31    1.448024e+11
# 2017-11-30    2.733817e+11
# 2017-12-31    1.533777e+11
# Freq: M, Name: VALUE, dtype: float64

# %%
open_m=sbr.OPEN.resample('M').first().values
open_m
# Out:
# array([173.4 , 172.59, 155.65, 160.77, 166.  , 156.4 , 146.65, 165.5 ,
#        183.85, 192.76, 194.49, 224.5 ])

# %%
close_m=sbr.CLOSE.resample('M').last().values
low_m=sbr.LOW.resample('M').min().values
high_m=sbr.HIGH.resample('M').max().values

# %%
month=sber.index.strftime('%b').unique()
month
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov', 'Dec'],
#       dtype='object', name='TRADEDATE')

# %%
moth_a=pd.DataFrame(
    {'month':month,'open':open_m,'close':close_m,'low':low_m,'high':high_m},
    index=sbr_vol_month.index)
moth_a.head(3)
# Out:
#            month    open  close     low    high
# TRADEDATE
# 2017-01-31   Jan  173.40  172.2  163.34  181.68
# 2017-02-28   Feb  172.59  156.0  155.70  174.98
# 2017-03-31   Mar  155.65  159.8  155.23  165.99

# %%
sb_m=sber.resample('m').agg({'OPEN':'first','LOW':'min','HIGH':'max','CLOSE':'last'})
sb_m
# Out:
#               OPEN     LOW    HIGH   CLOSE
# TRADEDATE
# 2017-01-31  173.40  163.34  181.68  172.20
# 2017-02-28  172.59  155.70  174.98  156.00
# 2017-03-31  155.65  155.23  165.99  159.80
# 2017-04-30  160.77  147.62  168.45  165.20
# 2017-05-31  166.00  155.03  172.39  155.93
# 2017-06-30  156.40  136.20  158.89  145.59
# 2017-07-31  146.65  146.22  167.35  164.53
# 2017-08-31  165.50  165.30  186.33  183.51
# 2017-09-30  183.85  180.93  195.00  192.33
# 2017-10-31  192.76  189.06  198.52  193.80
# 2017-11-30  194.49  192.38  233.95  224.35
# 2017-12-31  224.50  219.23  230.50  225.20

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2748/3741687927.py in <module>
# ----> 1 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#       2 import plotly.graph_objs as go
#       3 init_notebook_mode(connected=True)
#
# ModuleNotFoundError: No module named 'plotly'

# %%
trace = go.Ohlc(x=sber.index,
                open=sber['OPEN'],
                high=sber['HIGH'],
                low=sber['LOW'],
                close=sber['CLOSE'])

data = [trace]
iplot(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2748/753995500.py in <module>
# ----> 1 trace = go.Ohlc(x=sber.index,
#       2                 open=sber['OPEN'],
#       3                 high=sber['HIGH'],
#       4                 low=sber['LOW'],
#       5                 close=sber['CLOSE'])
#
# NameError: name 'go' is not defined

# %%
trace2 = go.Ohlc(x=sb_m.index,# Проблема месяц, есть ли решение на середину месяца
                open=sb_m['OPEN'],
                high=sb_m['HIGH'],
                low=sb_m['LOW'],
                close=sb_m['CLOSE'])


layout = go.Layout(
    xaxis = dict(
        rangeslider = dict(
            visible = False
        )
    )
)

data2 = [trace2]
fig = go.Figure(data=data2,layout=layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2748/1062797474.py in <module>
# ----> 1 trace2 = go.Ohlc(x=sb_m.index,# Проблема месяц, есть ли решение на середину месяца
#       2                 open=sb_m['OPEN'],
#       3                 high=sb_m['HIGH'],
#       4                 low=sb_m['LOW'],
#       5                 close=sb_m['CLOSE'])
#
# NameError: name 'go' is not defined

# %%
sb_m=sber.resample('M').agg({'OPEN':'first','LOW':'min','HIGH':'max','CLOSE':'last'})
sb_m
# Out:
#               OPEN     LOW    HIGH   CLOSE
# TRADEDATE
# 2017-01-31  173.40  163.34  181.68  172.20
# 2017-02-28  172.59  155.70  174.98  156.00
# 2017-03-31  155.65  155.23  165.99  159.80
# 2017-04-30  160.77  147.62  168.45  165.20
# 2017-05-31  166.00  155.03  172.39  155.93
# 2017-06-30  156.40  136.20  158.89  145.59
# 2017-07-31  146.65  146.22  167.35  164.53
# 2017-08-31  165.50  165.30  186.33  183.51
# 2017-09-30  183.85  180.93  195.00  192.33
# 2017-10-31  192.76  189.06  198.52  193.80
# 2017-11-30  194.49  192.38  233.95  224.35
# 2017-12-31  224.50  219.23  230.50  225.20

# %%
sb_m=sber.resample('MS').agg({'OPEN':'first','LOW':'min','HIGH':'max','CLOSE':'last'})
sb_m
# Out:
#               OPEN     LOW    HIGH   CLOSE
# TRADEDATE
# 2017-01-01  173.40  163.34  181.68  172.20
# 2017-02-01  172.59  155.70  174.98  156.00
# 2017-03-01  155.65  155.23  165.99  159.80
# 2017-04-01  160.77  147.62  168.45  165.20
# 2017-05-01  166.00  155.03  172.39  155.93
# 2017-06-01  156.40  136.20  158.89  145.59
# 2017-07-01  146.65  146.22  167.35  164.53
# 2017-08-01  165.50  165.30  186.33  183.51
# 2017-09-01  183.85  180.93  195.00  192.33
# 2017-10-01  192.76  189.06  198.52  193.80
# 2017-11-01  194.49  192.38  233.95  224.35
# 2017-12-01  224.50  219.23  230.50  225.20

# %%
trace2 = go.Ohlc(x=sb_m.index,# Проблема месяц, есть ли решение на середину месяца
                open=sb_m['OPEN'],
                high=sb_m['HIGH'],
                low=sb_m['LOW'],
                close=sb_m['CLOSE'])


# layout = go.Layout(
#     xaxis = dict(
#         rangeslider = dict(
#             visible = False
#         )
#     )
# )

data2 = [trace2]
fig = go.Figure(data=data2)#,layout=layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2748/2609315613.py in <module>
# ----> 1 trace2 = go.Ohlc(x=sb_m.index,# Проблема месяц, есть ли решение на середину месяца
#       2                 open=sb_m['OPEN'],
#       3                 high=sb_m['HIGH'],
#       4                 low=sb_m['LOW'],
#       5                 close=sb_m['CLOSE'])
#
# NameError: name 'go' is not defined

# %%
month=sber.index.strftime('%b').unique()

trace2 = go.Candlestick(
                x=month, # Внимание на месяц
                open=sb_m['OPEN'],
                high=sb_m['HIGH'],
                low=sb_m['LOW'],
                close=sb_m['CLOSE'])


# layout = go.Layout(
#     xaxis = dict(
#         rangeslider = dict(
#             visible = False
#         )
#     )
# )

data2 = [trace2]
fig = go.Figure(data=data2)#,layout=layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2748/1622089778.py in <module>
#       1 month=sber.index.strftime('%b').unique()
#       2
# ----> 3 trace2 = go.Candlestick(
#       4                 x=month, # Внимание на месяц
#       5                 open=sb_m['OPEN'],
#
# NameError: name 'go' is not defined

# %%
sbr.LOW.resample('M').min()
# Out:
# TRADEDATE
# 2017-01-31    163.34
# 2017-02-28    155.70
# 2017-03-31    155.23
# 2017-04-30    147.62
# 2017-05-31    155.03
# 2017-06-30    136.20
# 2017-07-31    146.22
# 2017-08-31    165.30
# 2017-09-30    180.93
# 2017-10-31    189.06
# 2017-11-30    192.38
# 2017-12-31    219.23
# Freq: M, Name: LOW, dtype: float64
