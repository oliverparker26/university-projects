# %% [markdown]
# Hello! this is my first notebook in Python.
# $$sin x$$

# %%
10+3

# %%
print("good job everyone!")

# %%
print('hey')

# %%
def adds(a,b,c):
        return(a+b+c)

# %%
adds(2,3,4)

# %%
# %pwd

# %%
a = "HELLO"

# %%
a.lower().upper()

# %%
5**3

# %%
def loh(a,b):
    if a > b: 
        print('ну ты и лох, чувак')
    
    else:
        print('реально лошара')

# %%
loh(2,5)

# %%
loh(4,2)

# %%
import numpy as np

# %%
#pip install num2words;

# %%
from num2words import num2words
num2words(42, lang='ru')

# %%
for ipp in range(4,2):
    a = num2words(ipp, lang='ru')
    print(a)

# %%
pop = range(1,10)
print(pop.reverse())

# %%
30%2==0

# %%
print("bfjd ") <br>

# %%
print('jf','\n')
print('hkd')

# %%
print?

# %%
from num2words import num2words

for ipp in range(1,11)[::-1]:
    a = num2words(ipp, lang = 'ru').capitalize()
    b = num2words(ipp-1, lang = 'ru').capitalize()
    if ipp % 10 == 1:
        a = 'Одна'
        print(a,"бутылка молока на борту",'\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну",'\n', b, "осталось на борту",'\n')
    elif ipp % 10 >= 5 or ipp % 10 == 0:
        print(a,"бутылок молока на борту", '\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну", '\n', b, "осталось на борту",'\n')
    elif ipp % 10 == 2:
         a = 'Две'
         print(a,"бутылки молока на борту", '\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну", '\n', b, "осталось на борту",'\n')
    else:
        print(a,"бутылки молока на борту", '\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну",'\n', b, "осталось на борту",'\n')
    
for ipp in range(11,20):
        a = num2words(ipp, lang = 'ru').capitalize()
        b =  num2words(ipp-1, lang = 'ru').capitalize()
        print (a, "бутылок молока на борту", '\n', a, "на борту", '\n',"Берёшь одну, пускаешь ко дну", '\n', b, "осталось на борту",'\n')

# %%
for ipp in range(20,100):
    a = num2words(ipp, lang = 'ru').capitalize()
    b = num2words(ipp-1, lang = 'ru').capitalize()
    if ipp % 10 == 1:
        a = b + ' одна'
        print(a,"бутылка молока на борту",'\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну",'\n', b, "осталось на борту",'\n')
    elif ipp % 10 >= 5 or ipp % 10 == 0:
        print(a,"бутылок молока на борту", '\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну", '\n', b, "осталось на борту",'\n')
    elif ipp % 10 == 2:
            c = num2words(ipp-2, lang = 'ru')
            a = c + ' две'
            print(a,"бутылки молока на борту", '\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну", '\n', b, "осталось на борту",'\n')
    else:
        print(a,"бутылки молока на борту", '\n', a, "на борту",'\n', "Берёшь одну, пускаешь ко дну", '\n', b, "осталось на борту",'\n')

# %%
n=range(1,10, -1)
print(n)

# %%
n = input()
print(range(1,100)[::-1])

# %%
print(range(1,100)[::-1])

# %%
b = (range(1,10)[0:7:-1])
for i in b:
    print(i)

# %%
array = [1,2,3]
a = array[2]
a
# Out:
# 3

# %%
a = [1,2,2,4]
b = [2,2,2]
a[1]==b[2]
# Out:
# True

# %%
#import numpy as np
#import pandas as pd
#from IPython.display import display

# https://openflights.org/data.html

url_airport = 'https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat'
url_routers = 'https://raw.githubusercontent.com/jpatokal/openflights/master/data/routes.dat'

df_raw_airport = pd.read_csv(url_airport)
display(df_raw_airport.head(5))
df_raw_routers = pd.read_csv(url_routers)
display(df_raw_routers.head(10))

columns_airport = ['Airport ID', 'Name', 'City',
                   'Country', 'IATA', 'ICAO', 'Latitude', 'Longitude', 'Altitude', 'Timezone',
                   'DST', 'Tz database time zone', 'Type', 'Source']

columns_routers = ['Airline', 'Airline ID', 'Source airport', 'Source airport ID', 
                   'Destination airport', 'Destination airport ID', 'Codeshare', 'Stops', 'Equipment']

df_raw_airport = pd.read_csv(url_airport, names = columns_airport)
display(df_raw_airport.head(3))
df_raw_routers = pd.read_csv(url_routers, names = columns_routers)
display(df_raw_routers.head(3))


df_raw_airport['Continent'] = 0.0
df_raw_airport
# Out:
#    1                               Goroka Airport        Goroka  \
# 0  2                               Madang Airport        Madang
# 1  3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 2  4                               Nadzab Airport        Nadzab
# 3  5  Port Moresby Jacksons International Airport  Port Moresby
# 4  6                  Wewak International Airport         Wewak
#
#    Papua New Guinea  GKA  AYGA  -6.081689834590001  145.391998291  5282  10  \
# 0  Papua New Guinea  MAG  AYMD           -5.207080     145.789001    20  10
# 1  Papua New Guinea  HGU  AYMH           -5.826790     144.296005  5388  10
# 2  Papua New Guinea  LAE  AYNZ           -6.569803     146.725977   239  10
# 3  Papua New Guinea  POM  AYPY           -9.443380     147.220001   146  10
# 4  Papua New Guinea  WWK  AYWK           -3.583830     143.669006    19  10
#
#    U  Pacific/Port_Moresby  airport  OurAirports
# 0  U  Pacific/Port_Moresby  airport  OurAirports
# ...
